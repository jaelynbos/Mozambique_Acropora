# %%
DB_5kb<-read.table('/scratch/jbos/Moz_aligned_mil/beagle_contigs_SppB/LD_pruned/5kb_LD_values.txt')

# %%
colnames(DB_5kb)
# Out:
# [1] "V1"

# %%
DB_5kb_cdf<-ecdf(DB_5kb$V1)

# %%
DB_5kb_cdf(0.249508)
# Out:
# [1] 0.9097095

# %%
DAN_5kb<-read.table('/scratch/jbos/Moz_aligned_mil/beagle_contigs_SppA_north/LD_pruned/5kb_LD_values_2nd.txt')

# %%
colnames(DAN_5kb)
# Out:
# [1] "V1"

# %%
DAN_5kb_cdf<-ecdf(DAN_5kb$V1)
DAN_5kb_cdf(0.162939)
# Out:
# [1] 0.9312441

# %%
DAS_5kb<-read.table('/scratch/jbos/Moz_aligned_mil/beagle_contigs_SppA_south/LD_pruned/5kb_LD_values_2nd.txt')

# %%
DAS_5kb_cdf<-ecdf(DAS_5kb$V1)
DAS_5kb_cdf(0.174687)
# Out:
# [1] 0.9423833
